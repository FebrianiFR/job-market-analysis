# %% [markdown]
# # Python Programming - Pair Assessment (30%)
#
# ### This is your assignment notebook.
#
# In this notebook you and your partner will write your pair assignment. Steps for submitting the assignment will be described on Learn. The assignment is due on 24th October 2024 at 2.00 pm.

# %% [markdown]
# ### 🎯Objective: Utilize Python to analyse a selected data set, address a specific business-related question and visually represent your findings.
#
# ### Instructions:
#
# - **Dataset Selection**: Choose <u>one</u> from the 3 provided datasets: job_market_insight.csv, london_airbnb_listing.csv, or NBA_game_report.xlsx. Reflect on the information each dataset contains and consider what types of questions these datasets can answer.
#
# - **Formulate a Business Question**: Develop a clear, concise business question that the chosen dataset can help answer. A good question should be straightforward but meaningful, aimed at uncovering insights that could potentially benefit a business scenario or decision-making process.
#
# - **Data Cleaning**: Before analysing your data, ensure to clean it. This may involve handling missing values, removing duplicates, correcting errors, or restructuring the dataset for better analysis.
#
# - **Data Analysis**: Apply methods and techniques you've learned so far to analyse your selected dataset to find answers to your formulated question. You are not expected to implement advanced models or algorithms; instead, concentrate on extracting insights through exploratory data analysis and effective visual representations.
#
#
# ### Deliverable:
#
# Submit a Jupyter Notebook containing:
#
# - **Python Code**: Include all the code used during your analysis. Your code should be well-organized and adequately commented to enhance readability. Good comments should be concise and informative, focused on explaining "why" something is done, not "what" is done, which should be obvious from the code.
#
# - **Graphical Representation**: Create a visual representation of your findings using <u>one</u> comprehensive graph for inclusion in your mini-report. This can be a single standalone graph or a combination of related graphs merged into a single display, such as side-by-side bar charts or an overlaid line chart on a bar chart. <br> **Note:** You may use other graphs to aid your analysis, and you are encouraged to include these intermediary graphs within your code for reference. However, your mini-report should feature only one final graph that distinctly presents your main findings.<u>Including more than one graph in the mini-report will result in a markdown.</u>
#
# - **Mini-report in Markdown**: Include a markdown cell that contains a mini-report (200 words +/- 10%). The report should outline the question you are addressing, its relevance, why you chose this particular dataset for your analysis, and the insights or answers your analysis has revealed regarding the business question.
#
# ### Allowed Libraries:
#
# For this assignment, you are restricted to using **only** the following libraries: numpy, pandas, matplotlib, and seaborn. <u>The use of any additional libraries not listed here will result in markdown points from the final score.</u>

# %% [markdown]
# ### Marking Rubric:
#
# The following table outlines the categories for assessment and their corresponding marks breakdown.
#
#
# | Criteria & Category                                                                 | Unsatisfactory (0-50%)                                                    | Good (50-60%)                                                      | Very Good (60-70%)                                                | Excellent (70%+)                                                  |
# |-------------------------------------------------------------------------------------|---------------------------------------------------------------------------|--------------------------------------------------------------------|------------------------------------------------------------------|-------------------------------------------------------------------|
# | **A) Business Question and Answer:** Identification of a business question that makes sense and clarity in the given answer based on data. Logical analysis is shown in the explanation. | Vaguely defined question and/or answer with minimal logical or data connection. | Clearly defined question with insufficient business relevance. The answer is shallow or overlooks data potential. | Clearly articulated question and answer that leverage data appropriately with sound reasoning. | Exceptionally well-articulated, clear, and relevant question and answer, demonstrating thorough logical analysis and optimal use of data. |
# | **B) Using the Data:** Suitability and robust use of the dataset, effective data cleaning, and clear justification of the analytical methods employed.| Ineffective and irrelevant data use, inappropriate dataset choice, and poor or absent data cleaning practices.| Adequate use of somewhat relevant data; superficial justification of methods. Basic data cleaning attempts that neglect deeper issues. | Very good use of relevant data, suitable dataset, solid justification of chosen methods, and effective data cleaning that addresses most data integrity issues. | Excellent data integration with a well-suited dataset, robust justification of methods, and comprehensive data cleaning practices ensuring high data quality and reliability. |
# | **C) Visualization:** The effectiveness of graphs or visuals in supporting and reinforcing the argument without inducing confusion or misleading the viewer. | Graphs/visuals are confusing, misleading, or irrelevant. | Graphs/visuals are adequate but may offer limited clarity or could be misinterpreted. | Good visuals that enhance understanding of the data with minimal errors. | Excellent, clear, and impactful visuals that strongly support and clarify the argument, enhancing overall comprehension. |
# | **D) Code Quality:** Cleanliness, conciseness, readability of code, and adherence to good coding practices, such as meaningful naming and DRY (don't repeat yourself) principles. | Code is poorly organized, hard to read, or exhibits poor coding practices. | Code is organized and readable with satisfactory naming conventions, but may have minor redundancies. | Code is clean, concise, and adheres well to good programming standards and practices. | Exemplary code: marked by pristine style, perfect readability, superior naming conventions, and strict adherence to best coding practices. |
# | **E) Code Structure:** Logical organization of code, effective use of comments, and documentation for clarity. Assessing modularity of the code. | Code lacks logical structure or modularity with minimal or no comments/documentation. | Code is somewhat organized, with basic comments and limited modularity. | Code is well-organized, well-documented, and demonstrates good modularity. | Excellent code structure, outstanding documentation, and high modularity enabling significant ease of reuse. |
#
#
# ### Calculation of Final Grade
#
# The final grade for this assignment will be the average of your points in all categories and contributes 30% to your total grade for the course. You and your partner will get the same grade. **Only one member per team should submit the work.**

# %% [markdown]
# #### 📝 How to edit a Jupyter Notebook:
#
# This notebook comprises two main types of cells:
#
# - **Code Cells**: These cells allow you to write and execute Python code. Edit the code as needed and run the cell to see the output.
# - **markdown cells**: Similar to this cell, markdown cells contain text. These cells use Markdown, a lightweight markup language. To edit a markdown cell, double-click on it, make your changes, and then press Shift + Enter or click the 'Run' button to format the text beautifully. Here's a quick guide to [Markdown Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **Cell Operations**
#
# - **Changing Cell Type**: You can change a cell's type (Code or Markdown) using the dropdown menu next to the 'Run' button in the toolbar.
#
# - **Adding Cells**: Add new cells to the notebook by clicking the **+** icon in the menu.

# %% [markdown]
# # Your submission goes below:

# %%
#importing the necessary library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


#load data
print(f'Below steps were perfromed to extract the details from the given dataset of job_market_analysis')
job = pd.read_csv('job_market_insight.csv', encoding='latin-1') #file is encoded using latin-1
print(f'Step 1: Load the Data. Data contains {len(job)} rows and {len(job.columns)} columns')

#Find out about duplicated data within the dataset
print(f'Step 2: Data contains {job.duplicated().sum()} duplicated rows. Removing the rows to ensure data uniqueness')

#drop all and keep first value since we want to collect unique data to see the salary distribution accross several roles and companies
job.drop_duplicates(inplace=True)

#remove rows with too many missing values, we set threshold that 9 out of 13 of the data must be filled in 
job.dropna(thresh=9, axis=0, inplace=True)
print(f'Step 3: Remove Data with 5 NAN values within a row. Data contains {len(job)} rows.')

#inspect missing value via graph 
print(f'Step 3: Inspecting Missing Value. Figure 1 Heatmap belows showing the distribution of missing value accross the dataset.')
sns.heatmap(job.isna(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Figure 1: Missing Value Distribuion')
print('Columns priortize to be handled: Min_Salary, Max_Salary, Avg_Salary (numerical variable)')
plt.show()

#fill in salary missing values
print('Step 4: Fill in Salary missing values')
#remove currency strings
def remove_currency(salary):
    return salary.str.replace('$', '', regex=False)

#apply the function to the salary columns
salary_columns = ['Min_Salary', 'Max_Salary', 'Avg_Salary']
job[salary_columns] = job[salary_columns].apply(remove_currency)

#fill in the salary by looking up the mean salary with the same job title, seniority, employer
def fill_salary(row_missing, salary_type):
    jobn = job[job[salary_type].notna()]
    same_title = jobn[jobn['Job Title']==row_missing['Job Title']]
    same_seniority = same_title[same_title['Seniority']==row_missing['Seniority']]
    same_company = same_seniority[same_seniority['Employer']==row_missing['Employer']]
    if len(same_company) >0: #look up data with the same title, seniority, and employer
        return pd.to_numeric(same_company[salary_type]).mean()
    elif len(same_seniority)>0: #look up data with the same title, and seniority
        return pd.to_numeric(same_seniority[salary_type]).mean()
    else: #look up data with the same title
        return pd.to_numeric(same_title[salary_type]).mean() 

#handling minimum salary missing value
for index, row in job[job['Min_Salary'].isna()].iterrows():
    job.loc[index,'Min_Salary'] = fill_salary(row,'Min_Salary')

#handling maximum salary missing value
for index, row in job[job['Max_Salary'].isna()].iterrows():
    job.loc[index,'Max_Salary'] = fill_salary(row,'Max_Salary')

#handling average salary missing value
for index, row in job[job['Avg_Salary'].isna()].iterrows():
    job.loc[index,'Avg_Salary'] = fill_salary(row,'Avg_Salary')

#handling missing values
sns.heatmap(job.isna(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Figure 2: Missing Value Distribuion after Handling')
plt.show()
#value inspection, identifying outliers
print(f'Step 5. Identifying Outlier')

#we will look at the distribution of data for Job Title, Position, Skill, Industry Type, Work Type, and Salary
print('5.1 Analysing Job Title Data in Figure 3 and cleaned data in Figure 4')
#Job Title Data Inspection
fig, ax = plt.subplots(1,2, figsize=(18, 6))
sns.countplot(data=job, y='Job Title', stat='count', ax=ax[0] )
ax[0].set_title('Figure 3: Job Title before Data Cleaning')
#plt.show()
#from the plot we can see there are some misstyped and different styling of capitalization
#therefore data needs to be fixed

#Get the value counts for 'Job Title'
title_counts = job['Job Title'].value_counts()

#Filter titles that has some missed types
titles_typos = title_counts[title_counts < 5].index


#fixing the typos in a form of dictionary
fixed_typos = ['Senior Supply Chain Data Analysts', 'Business Systems Analysts',
       'Financial and Operational Analysts', 'Business Systems Analysts',
       'Business and Technical Analysts', 'Senior Data Analysts',
       'Senior Business Intelligence Analysts',
       'Financial and Operational Analysts', 'Senior Supply Chain Data Analysts']
fixed_titles = dict(zip(titles_typos, fixed_typos))

#fixing the typos by replacing values based on key and index
job['Job Title'] = job['Job Title'].replace(fixed_titles)

#re-plot the data
sns.countplot(data=job, y='Job Title', stat='count', ax=ax[1])
ax[1].set_title('Figure 4: Job Title after Data Cleaning')
plt.tight_layout()
plt.show()

#looking at the analyst position
print('5.2  Analysing the Position Data in Figure 5, As per this graph analyst is the most required postion in the job market.')
sns.countplot(data=job, y='Position', stat='count')
plt.title('Figure 5: Position')
plt.show()
#from this graph we can see there are a lot of 'Analyst' position in the market
#no data cleaning is needed


#looking at the Skill data, there are inconsistency and duplication within the data, therefore we will clean it
print('5.3 cleanig of the Skills column')
#steps to clean skill: make it uppercase -> remove white space before comma -> make it as a list -> make it as a set
#set to remove duplicate
job['skill_clean'] = job.apply(lambda row: set(list(row.Skill.upper().replace(', ',',').split(','))), axis = 1)


#no data cleaning is needed in work type

print('5.4 Analysis of Industry Type column via Figure 6 and cleaned data in Figure 7')
job['Industry Type'].value_counts()

#we will replace Other into Others to make it consitent
fig, ax = plt.subplots(1,2, figsize=(18, 6))
sns.countplot(data=job, y='Industry Type', stat='count', ax=ax[0] )
ax[0].set_title('Figure 6: Industry Type before Data Cleaning')
#plt.show()
job.loc[:,'Industry Type'] = job.loc[:,'Industry Type'].replace('Other','Others')

sns.countplot(data=job, y='Industry Type', stat='count', ax=ax[1] )
ax[1].set_title('Figure 7: Industry Type after Data Cleaning')
plt.show()

print('5.5 Cleaning of the Salary Data before and after graph')
print('Before Data Cleaning')
#change data type object to numeric
salary = ['Min_Salary','Avg_Salary','Max_Salary']
job[salary]=job[['Min_Salary','Avg_Salary','Max_Salary']].apply(pd.to_numeric)

#plot data distribution
fig, ax = plt.subplots(1,3, figsize=(18,6))
for i in range(3):
    sns.histplot(data=job, x=salary[i], stat='count', ax=ax[i] )
    ax[i].set_title(salary[i])
plt.show()
#from the graph we can see there is outlier and invalid data 


#max-salary: near 0 value
print('After Data Cleaning')
#min-salary: negative value and very high value
job[(job['Min_Salary']<1000) | (job['Min_Salary']>1000000)]

#on index 1773 data was written as '-87360'fix the data due to negative value
job.loc[1773, 'Min_Salary'] = 87360

#on index 1147 data was writtern as '1160000', eliminate the last 0
job.loc[1147, 'Min_Salary'] = 116000

#on index 1676 data was written as '42' fix the data into 42000
job.loc[1676, 'Min_Salary'] = 116000


#avg-salary:near 0 value
job[(job['Avg_Salary']<1000)]

#on index 1676 data was written as '62.5' fix the data into 62500
job.loc[1217, 'Avg_Salary'] = 62500

#find data that has less than 1000 salary
job[(job['Max_Salary']<1000)]

#on index 46 data was written as 57.2 fix data into 57200
job.loc[46, 'Avg_Salary'] = 57200

#on index 1132 data was written as 620 fix data into 620000
job.loc[1132, 'Avg_Salary'] = 62000

#on index 1692 data was written as 10.0 fix data into 10000
job.loc[1692, 'Avg_Salary'] = 100000


#plot data distribution
fig, ax = plt.subplots(1,3, figsize=(18,6))
for i in range(3):
    sns.histplot(data=job, x=salary[i], stat='count', ax=ax[i] )
    ax[i].set_title(salary[i])
plt.show()
# Out:
# Below steps were perfromed to extract the details from the given dataset of job_market_analysis
# Step 1: Load the Data. Data contains 1796 rows and 13 columns
# Step 2: Data contains 129 duplicated rows. Removing the rows to ensure data uniqueness
# Step 3: Remove Data with 5 NAN values within a row. Data contains 1666 rows.
# Step 3: Inspecting Missing Value. Figure 1 Heatmap belows showing the distribution of missing value accross the dataset.
# Columns priortize to be handled: Min_Salary, Max_Salary, Avg_Salary (numerical variable)
# Step 4: Fill in Salary missing values
# Step 5. Identifying Outlier
# 5.1 Analysing Job Title Data in Figure 3 and cleaned data in Figure 4
# 5.2  Analysing the Position Data in Figure 5, As per this graph analyst is the most required postion in the job market.
# 5.3 cleanig of the Skills column
# 5.4 Analysis of Industry Type column via Figure 6 and cleaned data in Figure 7
# 5.5 Cleaning of the Salary Data before and after graph
# ...

# %%
#slicing the data to investigate the job analyst position
job_analyst = job[job['Position']=='Analyst']

#to get information more on what skills needed to be an analyst, we will count the occurances of skills
print('Below is Final analysis based on how the salary of an analyst vary across different industries, and what are the most in-demand skills for this position in the job market. \n')
fig, ax = plt.subplots(1,2, figsize=(18,6))

#pivot the table to get the average salary 
industry_worktype = job_analyst.groupby(['Industry Type', 'Work Type'])['Avg_Salary'].mean().unstack()
industry_worktype.plot(kind='bar', stacked=False, ax=ax[0], color=['cornflowerblue', 'lightcoral','seagreen'])
ax[0].set_title("Figure 1. Average Salary Analyst Postion by Industry Type and Work Type")
ax[0].set_xlabel('Industry Type')
ax[0].set_ylabel('Average Salary ($)')


#create plot for the top skills
#split and flatten the 'skill_clean' column into individual skills
all_skills = job_analyst['skill_clean'].explode()

#count the occurrences of each skill
skill_counts = all_skills.value_counts()

#display the most mentioned skills
sns.barplot(y=skill_counts.index[:5], x=skill_counts.values[:5]/len(job_analyst)*100,ax=ax[1], color='slateblue')
for i, v in enumerate(skill_counts.values[:5]/len(job_analyst)*100):
    ax[1].text(v + 0.2, i, f'{v:.2f}%', va='center')
    
ax[1].set_title('Figure 2. Top 5 Most Wanted Skills for Analysts Position')
#ax[1].set_xlabel('Count')
ax[1].set_ylabel('Skill')
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False)
ax[1].get_xaxis().set_ticks([])

plt.tight_layout()
plt.show()
# Out:
# Below is Final analysis based on how the salary of an analyst vary across different industries, and what are the most in-demand skills for this position in the job market.

# %% [markdown]
# ### How does the salary of an analyst vary across different industries, and what are the most in-demand skills for this position in the job market?
#
# The job market data analysis states that the highest demand is for the analyst position of 43%. For reference, it is important to investigate how does the average salary is different across industries and work type(Figure 1) and what are the common skills that the employers are looking at while hiring an analyst(Figure 2).
#
# As per the graph, the legal industry offers the highest average salary around \\$105875 with remote work type and the travel industry offers the lowest average salary around \\$43720.280 with in-person work type. The trend states that people are still being paid more in in-person work type across industry. There is also a difference in average salary for the same industry with different work type.
#
# As for the skills, the top most required skill by employers across all industry for an analyst position are SQL, Excel, Python, Power BI, Tableau. This states candidate to have good technical skill and strong Business Intelligence tool knowledge.
#
# As a candidate, it is beneficial to have the necessary skills to have more earning and get the highest paid industry. On the other hand, by benchmarking, company can strategically formulate a competitive offer to attract the top talent.
